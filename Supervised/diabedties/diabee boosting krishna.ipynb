# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
d=pd.read_csv("diabetes.csv")
d.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
d.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
d.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# Glucose                   0.331357  0.221071                  0.137337
# BloodPressure             0.088933  0.281805                  0.041265
# SkinThickness             0.436783  0.392573                  0.183928
# Insulin                   1.000000  0.197859                  0.185071
# BMI                       0.197859  1.000000                  0.140647
# DiabetesPedigreeFunction  0.185071  0.140647                  1.000000
# Age                      -0.042163  0.036242                  0.033561
# Outcome                   0.130548  0.292695                  0.173844
#
#                                Age   Outcome
# Pregnancies               0.544341  0.221898
# Glucose                   0.263514  0.466581
# BloodPressure             0.239528  0.065068
# SkinThickness            -0.113970  0.074752
# Insulin                  -0.042163  0.130548
# BMI                       0.036242  0.292695
# DiabetesPedigreeFunction  0.033561  0.173844
# Age                       1.000000  0.238356
# Outcome                   0.238356  1.000000

# %%
sns.boxplot(data=d)
plt.show();

# %%
d.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
col=['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age']

# %%
for i in col:
    sns.boxplot(d[i])
    plt.figure()

# %%
sns.boxplot(d["Pregnancies"])
plt.show();

q3=d["Pregnancies"].quantile(0.75)
q1=d["Pregnancies"].quantile(0.25)
iqr=q3-q1
print(f"iqr:{iqr}")

upper_whisker=q3+1.5*iqr
lower_whisker=q1-1.5*iqr
print(f"upper_whisker: {upper_whisker}")
print(f"lower_whisker: {lower_whisker}")

upper_whisker_Pregnancies=d[d["Pregnancies"]>upper_whisker].index
print(f"upper_whisker_Pregnancies: {upper_whisker_Pregnancies}")

d.loc[upper_whisker_Pregnancies,"Pregnancies"]=np.nan
d.fillna(upper_whisker,inplace=True)

sns.boxplot(d["Pregnancies"])
plt.show();
# Out:
# iqr:5.0
# upper_whisker: 13.5
# lower_whisker: -6.5
# upper_whisker_Pregnancies: Int64Index([88, 159, 298, 455], dtype='int64')

# %%
sns.boxplot(d["Glucose"])
plt.show();

q3=d["Glucose"].quantile(0.75)
q1=d["Glucose"].quantile(0.25)
iqr=q3-q1
print(f"iqr:{iqr}")

upper_whisker=q3+1.5*iqr
lower_whisker=q1-1.5*iqr
print(f"upper_whisker:{upper_whisker}")
print(f"lower_whisker:{lower_whisker}")

lower_whisker_Glucose=d[d["Glucose"]<lower_whisker].index
print(f"lower_whisker_glucose:{lower_whisker_Glucose}")

d.loc[lower_whisker_Glucose,"Glucose"]=np.nan
d.fillna(lower_whisker,inplace=True)

sns.boxplot(d["Glucose"])
plt.show();
# Out:
# iqr:41.25
# upper_whisker:202.125
# lower_whisker:37.125
# lower_whisker_glucose:Int64Index([75, 182, 342, 349, 502], dtype='int64')

# %%
sns.boxplot(d["BloodPressure"])
plt.show();

q3=d["BloodPressure"].quantile(0.75)
q1=d["BloodPressure"].quantile(0.25)
iqr=q3-q1
print(f"iqr:{iqr}")

uperwhisker=q3+1.5*iqr
lowerwhisker=q1-1.5*iqr
print(f"uperwhisker:{uperwhisker}")
print(f"lowerwhisker:{lowerwhisker}")

upperwhiskek_BloodPressure=d[d["BloodPressure"]>uperwhisker].index
print(f"upperwhiskek_BloodPressure:{upperwhiskek_BloodPressure}")
lowerwhisker_BloodPressure=d[d["BloodPressure"]<lowerwhisker].index
print(f"lowerwhisker_BloodPressure:{lowerwhisker_BloodPressure}")

d.loc[upperwhiskek_BloodPressure,"BloodPressure"]=np.nan
d.fillna(uperwhisker,inplace=True)
d.loc[lowerwhisker_BloodPressure,"BloodPressure"]=np.nan
d.fillna(lowerwhisker,inplace=True)

sns.boxplot(d["BloodPressure"])
plt.show();
# Out:
# iqr:18.0
# uperwhisker:107.0
# lowerwhisker:35.0
# upperwhiskek_BloodPressure:Int64Index([43, 84, 106, 177, 362, 549, 691], dtype='int64')
# lowerwhisker_BloodPressure:Int64Index([  7,  15,  18,  49,  60,  78,  81, 125, 172, 193, 222, 261, 266,
#             269, 300, 332, 336, 347, 357, 426, 430, 435, 453, 468, 484, 494,
#             522, 533, 535, 589, 597, 601, 604, 619, 643, 697, 703, 706],
#            dtype='int64')

# %%
sns.boxplot(d["Insulin"])
plt.show();

q3=d["Insulin"].quantile(0.75)
q1=d["Insulin"].quantile(0.25)
iqr=q3-q1
print(f"iqr:{iqr}")

upperws=q3+1.5*iqr
lowerws=q1-1.5*iqr
print(f"upperwis:{upperws}")
print(f"lowerwis:{lowerws}")

upperws_Insulin=d[d["Insulin"]>upperws].index
print(f"upperws_Insulin:{upperws_Insulin}")

d.loc[upperws_Insulin,"Insulin"]=np.nan
d.fillna(upperws,inplace=True)

sns.boxplot(d["Insulin"])
plt.show();
# Out:
# iqr:127.25
# upperwis:318.125
# lowerwis:-190.875
# upperws_Insulin:Int64Index([  8,  13,  54, 111, 139, 153, 186, 220, 228, 231, 247, 248, 258,
#             286, 296, 360, 370, 375, 392, 409, 415, 480, 486, 519, 574, 584,
#             612, 645, 655, 695, 707, 710, 715, 753],
#            dtype='int64')

# %%
sns.boxplot(d["BMI"])
plt.show();

q3=d["BMI"].quantile(0.75)
q1=d["BMI"].quantile(0.25)
iqr=q3-q1
print(f"iqr:{iqr}\n\n")
upperws=q3+1.5*iqr
lowerws=q1-1.5*iqr
print(f"upperws:{upperws}")
print(f"lowerws:{lowerws}\n\n")
upperwis_bmi=d[d["BMI"]>upperws].index
lowerwis_bmi=d[d["BMI"]<lowerws].index
print(f"upperwis:{upperwis_bmi}\n lowerwis_bmi:{lowerwis_bmi}\n\n")

d.loc[upperwis_bmi,"BMI"]=np.nan
d.fillna(upperws,inplace=True)
d.loc[lowerwis_bmi,"BMI"]=np.nan
d.fillna(lowerws,inplace=True)

sns.boxplot(d["BMI"])
plt.show();
# Out:
# iqr:9.3
#
#
# upperws:50.550000000000004
# lowerws:13.35
#
#
# upperwis:Int64Index([120, 125, 177, 193, 247, 303, 445, 673], dtype='int64')
#  lowerwis_bmi:Int64Index([9, 49, 60, 81, 145, 371, 426, 494, 522, 684, 706], dtype='int64')

# %%
sns.boxplot(d["DiabetesPedigreeFunction"])
plt.show();

q3=d["DiabetesPedigreeFunction"].quantile(0.75)
q1=d["DiabetesPedigreeFunction"].quantile(0.25)
iqr=q3-q1
print(f"iqr:{iqr}\n")

upperws=q3+1.5*iqr
lowerws=q1-1.5*iqr
print(f"upperws:{upperws}\n lowerws:{lowerws}\n\n")

upperws_DiabetesPedigreeFunction=d[d["DiabetesPedigreeFunction"]>upperws].index
print(f"upperws_DiabetesPedigreeFunction:{upperws_DiabetesPedigreeFunction}\n\n")

d.loc[upperws_DiabetesPedigreeFunction,"DiabetesPedigreeFunction"]=np.nan
d.fillna(upperws,inplace=True)

sns.boxplot(d["DiabetesPedigreeFunction"])
plt.show();
# Out:
# iqr:0.38249999999999995
#
# upperws:1.2
#  lowerws:-0.32999999999999996
#
#
# upperws_DiabetesPedigreeFunction:Int64Index([  4,  12,  39,  45,  58, 100, 147, 187, 218, 228, 243, 245, 259,
#             292, 308, 330, 370, 371, 383, 395, 445, 534, 593, 606, 618, 621,
#             622, 659, 661],
#            dtype='int64')

# %%
sns.boxplot(d["Age"])
plt.show();

q3=d["Age"].quantile(0.75)
q1=d["Age"].quantile(0.25)
iqr=q3-q1
print(f"iqr={iqr}\n")

upperws=q3+1.5*iqr
lowerws=q1-1.5*iqr
print(f"upperws:{upperws}\n lowerws:{lowerws}\n")

upperws_age=d[d["Age"]>upperws].index
print(f"upperws_age:{upperws_age}\n\n")

d.loc[upperws_age,"Age"]=np.nan
d.fillna(upperws,inplace=True)

sns.boxplot(d["Age"])
plt.show();
# Out:
# iqr=17.0
#
# upperws:66.5
#  lowerws:-1.5
#
# upperws_age:Int64Index([123, 363, 453, 459, 489, 537, 666, 674, 684], dtype='int64')

# %%
sns.boxplot(d["SkinThickness"])
plt.show();

q3=d["SkinThickness"].quantile(0.75)
q1=d["SkinThickness"].quantile(0.25)
iqr=q3-q1
print(f"iqr:{iqr}\n")
      
uppersw=q3+1.5*iqr
lowersw=q1-1.5*iqr
print(f"uppersw:{uppersw}\nlowersw:{lowersw}\n")

uppersw_SkinThickness=d[d["SkinThickness"]>uppersw].index
print(f"uppersw_SkinThickness:{uppersw_SkinThickness}\n\n")

d.loc[uppersw_SkinThickness,"SkinThickness"]=np.nan
d.fillna(uppersw,inplace=True)

sns.boxplot(d["SkinThickness"])
plt.show();
# Out:
# iqr:32.0
#
# uppersw:80.0
# lowersw:-48.0
#
# uppersw_SkinThickness:Int64Index([579], dtype='int64')

# %%
sns.boxplot(data=d)
# Out:
# <AxesSubplot:>

# %%
col=d.columns
col
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
from scipy.stats import skew

for i in col:
    print(i)
    print(skew(d[i]))
    plt.figure()
    sns.distplot(d[i])
    plt.show();
# Out:
# Pregnancies
# 0.8522929480775797
# Glucose
# 0.41712947618943413
# BloodPressure
# -0.4052420594003274
# SkinThickness
# 0.026610876128333412
# Insulin
# 1.1716041064979745
# BMI
# 0.13554320291395314
# DiabetesPedigreeFunction
# 1.022425881265123
# Age
# 1.0650848744423982
# Outcome
# 0.6337757030614577

# %%
d["Age"]=np.log(d["Age"])
print(skew(d["Age"]))

print(sns.distplot(d["Age"]))
plt.show();
# Out:
# 0.579826684023112
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
x=d.iloc[:,:-1]
print(x)
y=d.iloc[:,-1]
print(y)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0    148.0           72.0           35.0      0.0  33.6
# 1            1.0     85.0           66.0           29.0      0.0  26.6
# 2            8.0    183.0           64.0            0.0      0.0  23.3
# 3            1.0     89.0           66.0           23.0     94.0  28.1
# 4            0.0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0    101.0           76.0           48.0    180.0  32.9
# 764          2.0    122.0           70.0           27.0      0.0  36.8
# 765          5.0    121.0           72.0           23.0    112.0  26.2
# 766          1.0    126.0           60.0            0.0      0.0  30.1
# 767          1.0     93.0           70.0           31.0      0.0  30.4
#
#      DiabetesPedigreeFunction       Age
# 0                       0.627  3.912023
# 1                       0.351  3.433987
# 2                       0.672  3.465736
# 3                       0.167  3.044522
# 4                       1.200  3.496508
# ..                        ...       ...
# 763                     0.171  4.143135
# 764                     0.340  3.295837
# 765                     0.245  3.401197
# 766                     0.349  3.850148
# 767                     0.315  3.135494
#
# [768 rows x 8 columns]
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
def model(mod):
    mod.fit(xtrain,ytrain)
    ypred=mod.predict(xtest)
    
    train=mod.score(xtrain,ytrain)
    test=mod.score(xtest,ytest)
    
    print(f"Training Accuracy: {train}\nTesting Accuracy: {test}\n\n")
    print(classification_report(ytest,ypred))
    return mod

# %%
from sklearn.metrics import classification_report
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier

# %%
ADAB=model(AdaBoostClassifier())
# Out:
# Training Accuracy: 0.8045602605863192
# Testing Accuracy: 0.8181818181818182
#
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87       107
#            1       0.71      0.68      0.70        47
#
#     accuracy                           0.82       154
#    macro avg       0.79      0.78      0.78       154
# weighted avg       0.82      0.82      0.82       154

# %%
GDB=model(GradientBoostingClassifier())
# Out:
# Training Accuracy: 0.9136807817589576
# Testing Accuracy: 0.8116883116883117
#
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.86       107
#            1       0.69      0.70      0.69        47
#
#     accuracy                           0.81       154
#    macro avg       0.78      0.78      0.78       154
# weighted avg       0.81      0.81      0.81       154

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\krishna\anaconda3\lib\site-packages (1.7.3)
# Requirement already satisfied: numpy in c:\users\krishna\anaconda3\lib\site-packages (from xgboost) (1.21.5)
# Requirement already satisfied: scipy in c:\users\krishna\anaconda3\lib\site-packages (from xgboost) (1.9.1)

# %%
from xgboost import XGBClassifier
XGB=model(XGBClassifier())
XG=model(XGBClassifier(max_depth=2))
# Out:
# Training Accuracy: 1.0
# Testing Accuracy: 0.7792207792207793
#
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.82      0.84       107
#            1       0.63      0.68      0.65        47
#
#     accuracy                           0.78       154
#    macro avg       0.74      0.75      0.75       154
# weighted avg       0.79      0.78      0.78       154
#
# Training Accuracy: 0.9006514657980456
# Testing Accuracy: 0.8051948051948052
#
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.86       107
#            1       0.66      0.74      0.70        47
#
#     accuracy                           0.81       154
#    macro avg       0.77      0.79      0.78       154
# weighted avg       0.81      0.81      0.81       154
